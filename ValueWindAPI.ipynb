# %% [markdown]
# ## Sim Manager

# %%
from Simulation import Simulation


library_path= r"M:\Projects\Cost Model\HiperSim\valuewind\Inputs"
CAPEX_sim = Simulation.from_config(library_path=library_path, config="Config.yaml")

# run the simulation
CAPEX_sim.run()

# plot the results
CAPEX_sim.results_collector.plot_wind_time_series()
CAPEX_sim.results_collector.plot_windFarm_response()
# Out:
# Loaded MetEnv data structure: {'ME': {'MetEnv': [{'name': 'Wind_speed', 'Parameters': {'Weibull_shape': 2, 'Weibull_scale': 8}}, {'name': 'Turbulence_Intensity', 'Parameters': {'TI': 10}}]}}
# Loaded CAPEX data structure: {'PA': {'cost_categories': [{'name': 'Production & Acquisition', 'subcategories': [{'name': 'Turbine', 'project_time': {'value': 5, 'unit': 'months'}, 'project_time_h': 3600, 'subsubcategories': [{'name': 'Generator', 'fixed_cost': 0, 'flag_material_cost': True, 'material': [{'name': 'Copper', 'mass': 5, 'CF': 2}, {'name': 'Steel', 'mass': 5, 'CF': 2}]}, {'name': 'Tower', 'fixed_cost': 1000000, 'flag_material_cost': False, 'material': {'name': '', 'mass': None, 'CF': None}}]}, {'name': 'Substructure', 'project_time': {'value': 5, 'unit': 'months'}, 'project_time_h': 3600, 'subsubcategories': [{'name': 'SubstructureWT', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}, {'name': 'SubstructureWT2', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}]}, {'name': 'Mooring', 'project_time': {'value': 5, 'unit': 'months'}, 'project_time_h': 3600, 'subsubcategories': [{'name': 'MooringWT', 'fixed_cost': 0, 'flag_material_cost': False, 'material': {'name': '', 'mass': None, 'CF': None}, 'flag_length_cost': False, 'cost_per_length': None}, {'name': 'Anchor', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}]}]}]}}
# Loaded Material data structure: {'MD': {'Commodity': [{'name': 'Steel', 'Parameters': {'material_cost': 10000, 'flag_GBM': False, 'mu': 0.05, 'sigma': 0, 'flag_JumpDif': True, 'mu_jump': 0.5, 'lambda_jump': 0.02, 'sigma_jump': 0.1}}, {'name': 'Copper', 'Parameters': {'material_cost': 50000, 'flag_GBM': False, 'mu': 0.05, 'sigma': 0, 'flag_JumpDif': True, 'mu_jump': 0.5, 'lambda_jump': 0.02, 'sigma_jump': 0.1}}]}}
# Loaded Finex data structure: {'FI': {'FINEX': [{'name': 'Debt', 'Parameters': {'interest_rate': 5}}]}}
# CAPEX results collected.
# FINEX discounted results collected.
# Wind speed data collected.
# Total capital cost for Turbine_event: 1612456.3045853581
# Total capital cost for Substructure_event: 48996504.36682866
# Total capital cost for Mooring_event: 24498252.18341433
# CAPEX results collected.
# FINEX discounted results collected.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#      10 # plot the results
#      11 CAPEX_sim.results_collector.plot_wind_time_series()
# ---> 12 CAPEX_sim.results_collector.plot_windFarm_response()
#
# File m:\Projects\Cost Model\HiperSim\valuewind\Simulation.py:133, in ResultsCollector.plot_windFarm_response(self)
#     131 def plot_windFarm_response(self):
#     132     """Plots the wind farm response time series from the individual Turbines in the WindFarm instance."""
# --> 133     for turbine in self.env.windFarm.turbines.values():
#     134         if not turbine.response_log.empty:
#     135             #convert to dataframe
#     136             response_df = pd.json_normalize(turbine.response_log['response'])
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1465, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1586, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1945, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File c:\Users\mograf\AppData\Local\anaconda3\envs\valuewind\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2182             from_this_thread.append(frame_custom_thread_id)
#    2184     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2185         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2187 frames_list = None
#    2189 if keep_suspended:
#    2190     # This means that we should pause again after a set next statement.
#
# File c:\Users\mograf\AppData\Local\anaconda3\envs\valuewind\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2254, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2251                 queue.put(internal_cmd)
#    2252                 wait_timeout = TIMEOUT_FAST
# -> 2254         notify_event.wait(wait_timeout)
#    2255         notify_event.clear()
#    2257 finally:
#
# File c:\Users\mograf\AppData\Local\anaconda3\envs\valuewind\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File c:\Users\mograf\AppData\Local\anaconda3\envs\valuewind\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Monte Carlo Runs

# %%
from Simulation import Simulation

# Set up the simulation with a configuration file
library_path= "M:\Projects\Cost Model\HiperSim\valuewind\Inputs"
CAPEX_sim = Simulation.from_config(library_path=library_path, config="Config.yaml")

# Run Monte Carlo simulations with 100 realizations
CAPEX_sim.run_monte_carlo(num_runs=100)

# Access the DataFrame with all simulation results
results_df = CAPEX_sim.all_results_df
print(results_df.describe())  # Basic statistical analysis
# Out:
# Type of config before isinstance check: <class 'str'>
# Full config path: M:\Projects\Cost Model\ValueWind\CAPEX\Inputs\Config.yaml
# Loaded CAPEX data structure: {'PA': {'cost_categories': [{'name': 'Production & Acquisition', 'subcategories': [{'name': 'Turbine', 'project_time': 60, 'subsubcategories': [{'name': 'Generator', 'fixed_cost': 0, 'flag_material_cost': True, 'material': [{'name': 'Copper', 'mass': 5, 'CF': 2}, {'name': 'Steel', 'mass': 5, 'CF': 2}]}, {'name': 'Tower', 'fixed_cost': 1000000, 'flag_material_cost': False, 'material': {'name': '', 'mass': None, 'CF': None}}]}, {'name': 'Substructure', 'project_time': 60, 'subsubcategories': [{'name': 'SubstructureWT', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}, {'name': 'SubstructureWT2', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}]}, {'name': 'Mooring', 'project_time': 60, 'subsubcategories': [{'name': 'MooringWT', 'fixed_cost': 0, 'flag_material_cost': False, 'material': {'name': '', 'mass': None, 'CF': None}, 'flag_length_cost': False, 'cost_per_length': None}, {'name': 'Anchor', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}]}]}]}}
# Loaded Material data structure: {'MD': {'Commodity': [{'name': 'Steel', 'Parameters': {'material_cost': 10000, 'flag_GBM': False, 'mu': 0.05, 'sigma': 0, 'flag_JumpDif': True, 'mu_jump': 0.5, 'lambda_jump': 0.02, 'sigma_jump': 0.1}}, {'name': 'Copper', 'Parameters': {'material_cost': 50000, 'flag_GBM': False, 'mu': 0.05, 'sigma': 0, 'flag_JumpDif': True, 'mu_jump': 0.5, 'lambda_jump': 0.02, 'sigma_jump': 0.1}}]}}
# Running simulation 1 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 62446974.08917689
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 2 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 3 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 4 / 100
# Total capital cost for Turbine_event: 1818343.33412858
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 5 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 6 / 100
# Total capital cost for Turbine_event: 1762672.7408026569
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 7 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 8 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 9 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 10 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 11 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 12 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 60017489.13057099
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 13 / 100
# Total capital cost for Turbine_event: 1918254.3995320671
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 14 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 59885674.47368327
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 15 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 16 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 17 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 62558299.691409916
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 18 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 65767720.34530406
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 19 / 100
# Total capital cost for Turbine_event: 1751458.6466309552
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 20 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 21 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 22 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 23 / 100
# Total capital cost for Turbine_event: 1783671.7426838926
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 24 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 62179293.504657656
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 25 / 100
# Total capital cost for Turbine_event: 1699208.410186078
# Total capital cost for Substructure_event: 69021086.20055065
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 26 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 65464299.22383759
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 27 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 28 / 100
# Total capital cost for Turbine_event: 1759392.5318251187
# Total capital cost for Substructure_event: 64880876.994185135
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 29 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 30 / 100
# Total capital cost for Turbine_event: 1719945.038531781
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 31 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 32 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 33 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 34 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 35 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 25929035.924232196
# Running simulation 36 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 37 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 38 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 27452472.957770173
# Running simulation 39 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 60510185.562748045
# Total capital cost for Mooring_event: 33131076.56114793
# Running simulation 40 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 41 / 100
# Total capital cost for Turbine_event: 1776254.7699069104
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 42 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 43 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 44 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 45 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 46 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 47 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 48 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 49 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 60156781.51125921
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 50 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 51 / 100
# Total capital cost for Turbine_event: 1764433.9657973163
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 52 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 53 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 54 / 100
# Total capital cost for Turbine_event: 1761941.529590163
# Total capital cost for Substructure_event: 63097019.94236319
# Total capital cost for Mooring_event: 28638125.152130973
# Running simulation 55 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 56 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 57 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 65329560.54908462
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 58 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 59 / 100
# Total capital cost for Turbine_event: 1813062.2186888433
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 34662154.561810486
# Running simulation 60 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 61 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 62 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 63 / 100
# Total capital cost for Turbine_event: 1768772.262758508
# Total capital cost for Substructure_event: 58432733.5273769
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 64 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 65 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 66 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 62263761.18079276
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 67 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 68 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 56528310.92235479
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 69 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 70 / 100
# Total capital cost for Turbine_event: 1761557.4815005632
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 71 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 31622503.116744846
# Running simulation 72 / 100
# Total capital cost for Turbine_event: 1755914.6151471066
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 73 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 74 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 75 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 76 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 77 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 78 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 31783190.877957772
# Running simulation 79 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 64956197.37643451
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 80 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 63323107.98304333
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 81 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 82 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61359537.48662345
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 83 / 100
# Total capital cost for Turbine_event: 1769396.187708864
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 84 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 85 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 86 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 87 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 66126721.24033057
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 88 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 59379652.54563542
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 89 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 90 / 100
# Total capital cost for Turbine_event: 1773050.822435076
# Total capital cost for Substructure_event: 65516434.26516711
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 91 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 92 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 93 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 94 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 31922525.703233026
# Running simulation 95 / 100
# Total capital cost for Turbine_event: 1767146.0238170312
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 96 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 32435248.92307921
# Running simulation 97 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 98 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 62377960.95627883
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 99 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Running simulation 100 / 100
# Total capital cost for Turbine_event: 1770415.2500126448
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# Monte Carlo simulation completed.
#        total_cost
# count       100.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0

# %% [markdown]
# ### Discount Test

# %%
from Simulation import Simulation


library_path= "M:\Projects\Cost Model\ValueWind\CAPEX\Inputs"
CAPEX_sim = Simulation.from_config(library_path=library_path, config="Config.yaml")

# run the simulation
CAPEX_sim.run()
#CAPEX_sim.run_monte_carlo(num_runs=10, until=100)


# Plot and analyze results
CAPEX_sim.results_collector.plot_total_costs()
CAPEX_sim.results_collector.analyze_costs()
# Out:
# Loaded CAPEX data structure: {'PA': {'cost_categories': [{'name': 'Production & Acquisition', 'subcategories': [{'name': 'Turbine', 'project_time': 60, 'subsubcategories': [{'name': 'Generator', 'fixed_cost': 0, 'flag_material_cost': True, 'material': [{'name': 'Copper', 'mass': 5, 'CF': 2}, {'name': 'Steel', 'mass': 5, 'CF': 2}]}, {'name': 'Tower', 'fixed_cost': 1000000, 'flag_material_cost': False, 'material': {'name': '', 'mass': None, 'CF': None}}]}, {'name': 'Substructure', 'project_time': 60, 'subsubcategories': [{'name': 'SubstructureWT', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}, {'name': 'SubstructureWT2', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}]}, {'name': 'Mooring', 'project_time': 60, 'subsubcategories': [{'name': 'MooringWT', 'fixed_cost': 0, 'flag_material_cost': False, 'material': {'name': '', 'mass': None, 'CF': None}, 'flag_length_cost': False, 'cost_per_length': None}, {'name': 'Anchor', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}]}]}]}}
# Loaded Material data structure: {'MD': {'Commodity': [{'name': 'Steel', 'Parameters': {'material_cost': 10000, 'flag_GBM': False, 'mu': 0.05, 'sigma': 0, 'flag_JumpDif': True, 'mu_jump': 0.5, 'lambda_jump': 0.02, 'sigma_jump': 0.1}}, {'name': 'Copper', 'Parameters': {'material_cost': 50000, 'flag_GBM': False, 'mu': 0.05, 'sigma': 0, 'flag_JumpDif': True, 'mu_jump': 0.5, 'lambda_jump': 0.02, 'sigma_jump': 0.1}}]}}
# Loaded Finex data structure: {'FI': {'FINEX': [{'name': 'Debt', 'Parameters': {'interest_rate': 5}}]}}
# CAPEX results collected.
# FINEX discounted results collected.
# Total capital cost for Turbine_event: 1771084.9023594137
# Total capital cost for Substructure_event: 61633220.00101158
# Total capital cost for Mooring_event: 30816610.00050579
# CAPEX results collected.
# FINEX discounted results collected.
# CAPEX Cost Summary:
# count    6.000000e+00
# mean     1.570349e+07
# std      1.655891e+07
# min      0.000000e+00
# 25%      8.283137e+05
# 50%      1.590831e+07
# 75%      3.081661e+07
# max      3.081661e+07
# Name: cost, dtype: float64
#
# FINEX Discounted Cost Summary:
# count    6.000000e+00
# mean     8.406943e+05
# std      8.864901e+05
# min      0.000000e+00
# 25%      4.434421e+04
# 50%      8.516594e+05
# 75%      1.649783e+06
# max      1.649783e+06
# Name: discounted_cost, dtype: float64

# %% [markdown]
# ## Plot wind time series generated

# %%
from Simulation import Simulation


library_path = r"M:\Projects\Cost Model\HiperSim\valuewind\Inputs"
CAPEX_sim = Simulation.from_config(library_path=library_path, config="Config.yaml")

# run the simulation
CAPEX_sim.run()

CAPEX_sim.results_collector.plot_wind_time_series()
CAPEX_sim.results_collector.plot_windFarm_response()
CAPEX_sim.results_collector.plot_WF_layout()
# Out:
# Loaded MetEnv data structure: {'ME': {'MetEnv': [{'name': 'Wind_speed', 'Parameters': {'Weibull_shape': 2, 'Weibull_scale': 8}}, {'name': 'Turbulence_Intensity', 'Parameters': {'TI': 10}}]}}
# Loaded surrogate model data from M:\Projects\Cost Model\HiperSim\valuewind\Inputs\WF_Model\constTSR_smooth.mat as nested dictionaries with NumPy array representation for 3D+ matrices.
# Loaded CAPEX data structure: {'PA': {'cost_categories': [{'name': 'Production & Acquisition', 'subcategories': [{'name': 'Turbine', 'project_time': {'value': 5, 'unit': 'months'}, 'project_time_h': 3600, 'subsubcategories': [{'name': 'Generator', 'fixed_cost': 0, 'flag_material_cost': True, 'material': [{'name': 'Copper', 'mass': 5, 'CF': 2}, {'name': 'Steel', 'mass': 5, 'CF': 2}]}, {'name': 'Tower', 'fixed_cost': 1000000, 'flag_material_cost': False, 'material': {'name': '', 'mass': None, 'CF': None}}]}, {'name': 'Substructure', 'project_time': {'value': 5, 'unit': 'months'}, 'project_time_h': 3600, 'subsubcategories': [{'name': 'SubstructureWT', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}, {'name': 'SubstructureWT2', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}]}, {'name': 'Mooring', 'project_time': {'value': 5, 'unit': 'months'}, 'project_time_h': 3600, 'subsubcategories': [{'name': 'MooringWT', 'fixed_cost': 0, 'flag_material_cost': False, 'material': {'name': '', 'mass': None, 'CF': None}, 'flag_length_cost': False, 'cost_per_length': None}, {'name': 'Anchor', 'fixed_cost': 0, 'flag_material_cost': True, 'material': {'name': 'Steel', 'mass': 2000, 'CF': 1.2}}]}]}]}}
# Loaded Material data structure: {'MD': {'Commodity': [{'name': 'Steel', 'Parameters': {'material_cost': 10000, 'flag_GBM': False, 'mu': 0.05, 'sigma': 0, 'flag_JumpDif': True, 'mu_jump': 0.5, 'lambda_jump': 0.02, 'sigma_jump': 0.1}}, {'name': 'Copper', 'Parameters': {'material_cost': 50000, 'flag_GBM': False, 'mu': 0.05, 'sigma': 0, 'flag_JumpDif': True, 'mu_jump': 0.5, 'lambda_jump': 0.02, 'sigma_jump': 0.1}}]}}
# Loaded Finex data structure: {'FI': {'FINEX': [{'name': 'Debt', 'Parameters': {'interest_rate': 5}}]}}
# CAPEX results collected.
# FINEX discounted results collected.
# Wind speed data collected.
# Total capital cost for Turbine_event: 1612456.3045853581
# Total capital cost for Substructure_event: 48996504.36682866
# Total capital cost for Mooring_event: 24498252.18341433
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# ...
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - Power_std: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_mean: One of the requested xi is out of bounds in dimension 0
# Interpolation error in DataCnt - TBMx_std: One of the requested xi is out of bounds in dimension 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File m:\Projects\Cost Model\HiperSim\valuewind\WindFarm.py:55, in WindFarm.run_hourly(self)
#      54 if self.start_time <= self.env.now <= self.end_time:
# ---> 55     self.get_WindFarmResponse()
#      56 yield self.env.timeout(1)
#
# File m:\Projects\Cost Model\HiperSim\valuewind\WindFarm.py:97, in WindFarm.get_WindFarmResponse(self)
#      96     # Calculate the response for the turbine based on Vreq, TIreq, Preq, and interp_type
# ---> 97     turbine.get_turbine_response(Vreq, TIreq, Preq, interp_type)
#      99 return None
#
# File m:\Projects\Cost Model\HiperSim\valuewind\Turbine.py:117, in Turbine.get_turbine_response(self, Vreq, TIreq, Preq, interp_type)
#     116 # Get the turbine response
# --> 117 response = self.surrogate_query.get_points_from_surrogate_spline(
#     118     Vreq, TIreq, Preq, self.sensor_names, interp_type
#     119 )
#     121 # Log the response along with the current simulation time from env
#
# File m:\Projects\Cost Model\HiperSim\valuewind\TurbineSurrogate.py:73, in TurbineSurrogateQuery.get_points_from_surrogate_spline(self, Vreq, TIreq, Preq, sensor_names, interp_type, names)
#      72 try:
# ---> 73     interpolator = RegularGridInterpolator(grid, values, method=interp_type)
#      74     query_points = np.array([Vreq, TIreq, Preq]).T
#
# File c:\Users\mograf\AppData\Local\anaconda3\Lib\site-packages\scipy\interpolate\_rgi.py:240, in RegularGridInterpolator.__init__(self, points, values, method, bounds_error, fill_value)
#     239 self.bounds_error = bounds_error
# --> 240 self.grid, self._descending_dimensions = _check_points(points)
#     241 self.values = self._check_values(values)
#
# File c:\Users\mograf\AppData\Local\anaconda3\Lib\site-packages\scipy\interpolate\_rgi.py:20, in _check_points(points)
#      17 for i, p in enumerate(points):
#      18     # early make points float
#      19     # see https://github.com/scipy/scipy/pull/17230
# ---> 20     p = np.asarray(p, dtype=float)
#      21     if not np.all(p[1:] > p[:-1]):
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 CAPEX_sim = Simulation.from_config(library_path=library_path, config="Config.yaml")
#       7 # run the simulation
# ----> 8 CAPEX_sim.run()
#      10 CAPEX_sim.results_collector.plot_wind_time_series()
#      11 CAPEX_sim.results_collector.plot_windFarm_response()
#
# File m:\Projects\Cost Model\HiperSim\valuewind\Simulation.py:50, in Simulation.run(self, until)
#      48 def run(self, until: Union[int, float, None] = None):
#      49     """Run the simulation."""
# ---> 50     self.env.run_simulation(until=until)
#      51     # Collect results after simulation
#      52     self.results_collector.collect_capex_results()
#
# File m:\Projects\Cost Model\HiperSim\valuewind\ValueWindEnv.py:24, in ValueWindEnv.run_simulation(self, until)
#      21 self.windFarm.start()
#      23 # Run the simulation up to the specified time or the Project_Duration
# ---> 24 self.run(until=until or self.config.Project_Duration_h)
#      26 # Call the Fatigue Analysis process after the simulation ends
#      27 self.windFarm.get_FatigueAnalysis()
#
# File c:\Users\mograf\AppData\Local\anaconda3\Lib\site-packages\simpy\core.py:246, in Environment.run(self, until)
#     244 try:
#     245     while True:
# --> 246         self.step()
#     247 except StopSimulation as exc:
#     248     return exc.args[0]  # == until.value
#
# File c:\Users\mograf\AppData\Local\anaconda3\Lib\site-packages\simpy\core.py:204, in Environment.step(self)
#     202 exc = type(event._value)(*event._value.args)
#     203 exc.__cause__ = event._value
# --> 204 raise exc
#
# KeyboardInterrupt:

# %% [markdown]
# UML Diagrams -- not working

# %%
import os
import subprocess



def generate_uml_diagrams(directory):

    py_files = [f for f in os.listdir(directory) if f.endswith('.py')]
    if not py_files:
        print("No Python files found in the directory.")
        return
    else:
        print("Python files found:", py_files)

    subprocess.run(['pyreverse', '-o', 'png', '-A', '-S', '-p', 'UML_Diagram', 'Data_classes.py', 'Turbine.py', 'WindFarm.py'])

    if not os.path.isdir(directory):
        raise ValueError(f"Directory '{directory}' does not exist.")

    os.chdir(directory)
    try:
        result = subprocess.run(
            ['pyreverse', '-o', 'png', '-A', '-S', '-p', 'UML_Diagram', '.'],  # -A and -S add attributes and associations
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True
        )

        if result.returncode != 0:
            print("Error generating UML diagrams:")
            print("Standard Output:", result.stdout)
            print("Standard Error:", result.stderr)
        else:
            print("UML diagrams generated successfully. Check for UML_Diagram_classes.png and UML_Diagram_packages.png.")
    except Exception as e:
        print(f"An error occurred: {e}")



# Usage example:
generate_uml_diagrams(r"M:\Projects\Cost Model\HiperSim\valuewind")
# Out:
# Python files found: ['CAPEX.py', 'Data_classes.py', 'FarmSurrogate.py', 'Fatigue_Analysis.py', 'File_Handling.py', 'FINEX.py', 'MetEnvironment.py', 'Simulation.py', 'Turbine.py', 'TurbineSurrogate.py', 'ValueWindEnv.py', 'WindFarm.py']

# %%
import os
import subprocess



def generate_uml_diagrams(directory):

    py_files = [f for f in os.listdir(directory) if f.endswith('.py')]
    if not py_files:
        print("No Python files found in the directory.")
        return
    else:
        print("Python files found:", py_files)

    #subprocess.run(['pyreverse', '-o', 'png', '-A', '-S', '-p', 'UML_Diagram', 'Turbine.py', 'WindFarm.py'])
    subprocess.run(['pyreverse', '-o', 'png', '-A', '-S', '-p', 'UML_Diagram',  'WindFarm.py'])
    if not os.path.isdir(directory):
        raise ValueError(f"Directory '{directory}' does not exist.")
    


generate_uml_diagrams(r"M:\Projects\Cost Model\HiperSim\valuewind")
# Out:
# Python files found: ['CAPEX.py', 'Data_classes.py', 'FarmSurrogate.py', 'Fatigue_Analysis.py', 'File_Handling.py', 'FINEX.py', 'MetEnvironment.py', 'Simulation.py', 'Turbine.py', 'TurbineSurrogate.py', 'ValueWindEnv.py', 'WindFarm.py']

# %%
import os
import subprocess

try:
    result = subprocess.run(
        'pyreverse -o dot -p UML_Diagram . | dot -Tpng -o UML_Diagram.png',
        shell=True,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True
    )

    if result.returncode != 0:
        print("Error generating UML diagrams:")
        print("Standard Output:", result.stdout)
        print("Standard Error:", result.stderr)
    else:
        print("UML diagrams generated successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Error generating UML diagrams:
# Standard Output:
# Standard Error: Error: <stdin>: syntax error in line 1 near 'parsing'
